# %%
import warnings
warnings.filterwarnings("ignore")

import os
from os.path import join

import pandas as pd
import numpy as np

import missingno as msno

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import KFold, cross_val_score
import xgboost as xgb
import lightgbm as lgb

import matplotlib.pyplot as plt
import seaborn as sns

data_dir = os.path.join(os.getenv('HOME'), 'work/kaggle_kakr_housing/data')

train_data_path = os.path.join(data_dir, 'train.csv')
sub_data_path = os.path.join(data_dir, 'test.csv')

# %%
train = pd.read_csv(train_data_path)
test = pd.read_csv(sub_data_path)

train['date'] = train['date'].apply(lambda i: i[:6]).astype(int)
test['date'] = test['date'].apply(lambda i: i[:6]).astype(int)

y = train['price']
del train['price']

del train['id']
del test['id']

train['area_ratio'] = train['sqft_living'] / train['sqft_lot']
test['area_ratio']  = test['sqft_living']  / test['sqft_lot']

train['zipcode'] = train['zipcode'].astype('category')
test['zipcode']  = test['zipcode'].astype('category')

# sns.kdeplot(y)

# train_len = len(data)
# data = pd.concat((data, sub), axis=0)
msno.matrix(train)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

def rmse(y_test, y_pred):
    return np.sqrt(mean_squared_error(np.expm1(y_test), np.expm1(y_pred)))


from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor

random_state=2020        

gboost = GradientBoostingRegressor(random_state=random_state)
xgboost = XGBRegressor(random_state=random_state)
lightgbm = LGBMRegressor(random_state=random_state)
rdforest = RandomForestRegressor(random_state=random_state)

models = [gboost, xgboost, lightgbm, rdforest]

# %%
def get_scores(models, train, y):
    df = {}

    for model in models:
        model_name = model.__class__.__name__

        X_train, X_test, y_train, y_test = train_test_split(train, y, random_state=random_state, test_size=0.2)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        df[model_name] = rmse(y_test, y_pred)
        score_df = pd.DataFrame(df, index=['RMSE']).T.sort_values('RMSE', ascending=False)

    return score_df

# %%
from sklearn.model_selection import GridSearchCV


def my_GridSearch(model, train, y, param_grid, verbose=2, n_jobs=5):
    # GridSearchCV 모델로 초기화
    grid_model = GridSearchCV(model, param_grid=param_grid, scoring='neg_mean_squared_error', \
                              cv=5, verbose=verbose, n_jobs=n_jobs)

    # 모델 fitting
    grid_model.fit(train, y)

    # 결과값 저장
    params = grid_model.cv_results_['params']
    score = grid_model.cv_results_['mean_test_score']

    # 데이터 프레임 생성
    results = pd.DataFrame(params)
    results['score'] = score

    # RMSLE 값 계산 후 정렬
    results['RMSLE'] = np.sqrt(-1 * results['score'])
    results = results.sort_values('RMSLE')

    return results

# %%
param_grid = {
    'n_estimators': [500, 700, 900],
    'max_depth': [9, 12, 15],
    'learning_rate': [0.08, 0.05],
    'num_leaves' : [15, 20]
}

y_log = np.log1p(y)

model = LGBMRegressor(random_state=random_state)
param_gained = my_GridSearch(model, train, y_log, param_grid, verbose=10, n_jobs=5)

best = param_gained.iloc[0]
print(best)

# 최적 파라미터로 모델 재학습
model = LGBMRegressor(
    max_depth    = int(best['max_depth']),
    n_estimators = int(best['n_estimators']),
    learning_rate= best['learning_rate'],
    num_leaves   = int(best['num_leaves']),
    random_state = random_state
)
model.fit(train, y_log)



# model = LGBMRegressor(param_gained, random_state=random_state)
# model.fit(train, y_log)
# # prediction = model.predict(test)
# # prediction
# prediction = np.expm1(model.predict(test))
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 4/5; 1/36] START learning_rate=0.08, max_depth=9, n_estimators=500, num_leaves=15
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.011783 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2586
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050660
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 4/5; 1/36] END learning_rate=0.08, max_depth=9, n_estimators=500, num_leaves=15;, score=-0.026 total time=   5.4s
# [CV 5/5; 2/36] START learning_rate=0.08, max_depth=9, n_estimators=500, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004196 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2552
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.035255
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 5/5; 2/36] END learning_rate=0.08, max_depth=9, n_estimators=500, num_leaves=20;, score=-0.023 total time=   4.7s
# [CV 4/5; 3/36] START learning_rate=0.08, max_depth=9, n_estimators=700, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009669 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2586
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050660
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 4/5; 3/36] END learning_rate=0.08, max_depth=9, n_estimators=700, num_leaves=15;, score=-0.026 total time=   5.5s
# [CV 3/5; 4/36] START learning_rate=0.08, max_depth=9, n_estimators=700, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002123 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2585
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.051670
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 3/5; 4/36] END learning_rate=0.08, max_depth=9, n_estimators=700, num_leaves=20;, score=-0.028 total time=   5.9s
# [CV 2/5; 5/36] START learning_rate=0.08, max_depth=9, n_estimators=900, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003996 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2581
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.052839
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 2/5; 5/36] END learning_rate=0.08, max_depth=9, n_estimators=900, num_leaves=15;, score=-0.027 total time=   6.8s
# [CV 1/5; 6/36] START learning_rate=0.08, max_depth=9, n_estimators=900, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002010 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050187
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 1/5; 6/36] END learning_rate=0.08, max_depth=9, n_estimators=900, num_leaves=20;, score=-0.026 total time=   7.8s
# [CV 1/5; 7/36] START learning_rate=0.08, max_depth=12, n_estimators=500, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002151 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050187
# [CV 1/5; 7/36] END learning_rate=0.08, max_depth=12, n_estimators=500, num_leaves=15;, score=-0.026 total time=   3.7s
# [CV 5/5; 7/36] START learning_rate=0.08, max_depth=12, n_estimators=500, num_leaves=15
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009516 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2552
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.035255
# [CV 5/5; 7/36] END learning_rate=0.08, max_depth=12, n_estimators=500, num_leaves=15;, score=-0.023 total time=   5.4s
# [CV 5/5; 8/36] START learning_rate=0.08, max_depth=12, n_estimators=500, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001721 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2552
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.035255
# [CV 5/5; 8/36] END learning_rate=0.08, max_depth=12, n_estimators=500, num_leaves=20;, score=-0.023 total time=   4.2s
# [CV 5/5; 9/36] START learning_rate=0.08, max_depth=12, n_estimators=700, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010820 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2552
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.035255
# [CV 5/5; 9/36] END learning_rate=0.08, max_depth=12, n_estimators=700, num_leaves=15;, score=-0.023 total time=   6.5s
# [CV 4/5; 10/36] START learning_rate=0.08, max_depth=12, n_estimators=700, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004059 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2586
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050660
# [CV 4/5; 10/36] END learning_rate=0.08, max_depth=12, n_estimators=700, num_leaves=20;, score=-0.026 total time=   6.8s
# [CV 4/5; 11/36] START learning_rate=0.08, max_depth=12, n_estimators=900, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004017 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2586
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050660
# [CV 4/5; 11/36] END learning_rate=0.08, max_depth=12, n_estimators=900, num_leaves=15;, score=-0.026 total time=   6.4s
# [CV 4/5; 12/36] START learning_rate=0.08, max_depth=12, n_estimators=900, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001948 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.[CV 1/5; 1/36] START learning_rate=0.08, max_depth=9, n_estimators=500, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007793 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050187
# [CV 1/5; 1/36] END learning_rate=0.08, max_depth=9, n_estimators=500, num_leaves=15;, score=-0.026 total time=   4.4s
# [CV 4/5; 2/36] START learning_rate=0.08, max_depth=9, n_estimators=500, num_leaves=20
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.010556 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2586
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050660
# [CV 4/5; 2/36] END learning_rate=0.08, max_depth=9, n_estimators=500, num_leaves=20;, score=-0.026 total time=   5.7s
# [CV 5/5; 3/36] START learning_rate=0.08, max_depth=9, n_estimators=700, num_leaves=15
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.043005 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2552
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.035255
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 5/5; 3/36] END learning_rate=0.08, max_depth=9, n_estimators=700, num_leaves=15;, score=-0.023 total time=   7.6s
# [CV 5/5; 4/36] START learning_rate=0.08, max_depth=9, n_estimators=700, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008794 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2552
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.035255
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 5/5; 4/36] END learning_rate=0.08, max_depth=9, n_estimators=700, num_leaves=20;, score=-0.023 total time=   7.0s
# [CV 5/5; 5/36] START learning_rate=0.08, max_depth=9, n_estimators=900, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006044 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2552
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.035255
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 5/5; 5/36] END learning_rate=0.08, max_depth=9, n_estimators=900, num_leaves=15;, score=-0.023 total time=   7.7s
# [CV 5/5; 6/36] START learning_rate=0.08, max_depth=9, n_estimators=900, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005828 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2552
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.035255
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 5/5; 6/36] END learning_rate=0.08, max_depth=9, n_estimators=900, num_leaves=20;, score=-0.023 total time=   8.3s
# [CV 1/5; 8/36] START learning_rate=0.08, max_depth=12, n_estimators=500, num_leaves=20
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.012046 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050187
# [CV 1/5; 8/36] END learning_rate=0.08, max_depth=12, n_estimators=500, num_leaves=20;, score=-0.027 total time=   5.3s
# [CV 1/5; 9/36] START learning_rate=0.08, max_depth=12, n_estimators=700, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004221 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050187
# [CV 1/5; 9/36] END learning_rate=0.08, max_depth=12, n_estimators=700, num_leaves=15;, score=-0.026 total time=   5.8s
# [CV 1/5; 10/36] START learning_rate=0.08, max_depth=12, n_estimators=700, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006123 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050187
# [CV 1/5; 10/36] END learning_rate=0.08, max_depth=12, n_estimators=700, num_leaves=20;, score=-0.027 total time=   6.0s
# [CV 1/5; 11/36] START learning_rate=0.08, max_depth=12, n_estimators=900, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001892 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050187
# [CV 1/5; 11/36] END learning_rate=0.08, max_depth=12, n_estimators=900, num_leaves=15;, score=-0.026 total time=   7.1s
# [CV 1/5; 12/36] START learning_rate=0.08, max_depth=12, n_estimators=900, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006822 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050187
# [CV 1/5; 12/36] END learning_rate=0.08, max_depth=12, n_estimators=900, num_leaves=20;, score=-0.027 total time=   8.5s[CV 3/5; 1/36] START learning_rate=0.08, max_depth=9, n_estimators=500, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004129 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2585
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.051670
# [CV 3/5; 1/36] END learning_rate=0.08, max_depth=9, n_estimators=500, num_leaves=15;, score=-0.028 total time=   4.5s
# [CV 3/5; 2/36] START learning_rate=0.08, max_depth=9, n_estimators=500, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004206 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2585
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.051670
# [CV 3/5; 2/36] END learning_rate=0.08, max_depth=9, n_estimators=500, num_leaves=20;, score=-0.028 total time=   4.6s
# [CV 3/5; 3/36] START learning_rate=0.08, max_depth=9, n_estimators=700, num_leaves=15
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.012065 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2585
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.051670
# [CV 3/5; 3/36] END learning_rate=0.08, max_depth=9, n_estimators=700, num_leaves=15;, score=-0.028 total time=   7.0s
# [CV 4/5; 4/36] START learning_rate=0.08, max_depth=9, n_estimators=700, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010191 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2586
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050660
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 4/5; 4/36] END learning_rate=0.08, max_depth=9, n_estimators=700, num_leaves=20;, score=-0.026 total time=   6.2s
# [CV 3/5; 5/36] START learning_rate=0.08, max_depth=9, n_estimators=900, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002051 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2585
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.051670
# [CV 3/5; 5/36] END learning_rate=0.08, max_depth=9, n_estimators=900, num_leaves=15;, score=-0.028 total time=   7.2s
# [CV 4/5; 6/36] START learning_rate=0.08, max_depth=9, n_estimators=900, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006224 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2586
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050660
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 4/5; 6/36] END learning_rate=0.08, max_depth=9, n_estimators=900, num_leaves=20;, score=-0.026 total time=   8.8s
# [CV 4/5; 7/36] START learning_rate=0.08, max_depth=12, n_estimators=500, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002070 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2586
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050660
# [CV 4/5; 7/36] END learning_rate=0.08, max_depth=12, n_estimators=500, num_leaves=15;, score=-0.026 total time=   4.4s
# [CV 3/5; 8/36] START learning_rate=0.08, max_depth=12, n_estimators=500, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008000 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2585
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.051670
# [CV 3/5; 8/36] END learning_rate=0.08, max_depth=12, n_estimators=500, num_leaves=20;, score=-0.027 total time=   4.6s
# [CV 3/5; 9/36] START learning_rate=0.08, max_depth=12, n_estimators=700, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003347 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2585
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.051670
# [CV 3/5; 9/36] END learning_rate=0.08, max_depth=12, n_estimators=700, num_leaves=15;, score=-0.027 total time=   5.9s
# [CV 2/5; 10/36] START learning_rate=0.08, max_depth=12, n_estimators=700, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004047 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2581
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.052839
# [CV 2/5; 10/36] END learning_rate=0.08, max_depth=12, n_estimators=700, num_leaves=20;, score=-0.027 total time=   6.1s
# [CV 2/5; 11/36] START learning_rate=0.08, max_depth=12, n_estimators=900, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004120 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2581
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.052839
# [CV 2/5; 11/36] END learning_rate=0.08, max_depth=12, n_estimators=900, num_leaves=15;, score=-0.027 total time=   7.0s
# [CV 2/5; 12/36] START learning_rate=0.08, max_depth=12, n_estimators=900, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002089 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2581
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.052839
# [CV 2/5; 12/36] END learning_rate=0.08, max_depth=12, n_estimators=900, num_leaves=20;, score=-0.027 total time=   8.1s
# [CV 2/5; 13/36] START learning_rate=0.08, max_depth=15, n_estimators=500, num_leaves=15
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.011968 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2581
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.052839
# [CV 2/5; 13/36] END learning_rate=0.08, max_depth=15, n_estimators=500, num_leaves=15;, score=-0.027 total time=   4.8s[CV 2/5; 1/36] START learning_rate=0.08, max_depth=9, n_estimators=500, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004523 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2581
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.052839
# [CV 2/5; 1/36] END learning_rate=0.08, max_depth=9, n_estimators=500, num_leaves=15;, score=-0.027 total time=   4.2s
# [CV 1/5; 2/36] START learning_rate=0.08, max_depth=9, n_estimators=500, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003217 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050187
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 1/5; 2/36] END learning_rate=0.08, max_depth=9, n_estimators=500, num_leaves=20;, score=-0.026 total time=   4.2s
# [CV 1/5; 3/36] START learning_rate=0.08, max_depth=9, n_estimators=700, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006482 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050187
# [CV 1/5; 3/36] END learning_rate=0.08, max_depth=9, n_estimators=700, num_leaves=15;, score=-0.026 total time=   5.8s
# [CV 1/5; 4/36] START learning_rate=0.08, max_depth=9, n_estimators=700, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008185 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050187
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 1/5; 4/36] END learning_rate=0.08, max_depth=9, n_estimators=700, num_leaves=20;, score=-0.026 total time=   7.3s
# [CV 1/5; 5/36] START learning_rate=0.08, max_depth=9, n_estimators=900, num_leaves=15
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032808 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050187
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 1/5; 5/36] END learning_rate=0.08, max_depth=9, n_estimators=900, num_leaves=15;, score=-0.026 total time=   7.9s
# [CV 2/5; 6/36] START learning_rate=0.08, max_depth=9, n_estimators=900, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010051 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2581
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.052839
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 2/5; 6/36] END learning_rate=0.08, max_depth=9, n_estimators=900, num_leaves=20;, score=-0.026 total time=   8.8s
# [CV 3/5; 7/36] START learning_rate=0.08, max_depth=12, n_estimators=500, num_leaves=15
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.011342 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2585
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.051670
# [CV 3/5; 7/36] END learning_rate=0.08, max_depth=12, n_estimators=500, num_leaves=15;, score=-0.027 total time=   5.5s
# [CV 4/5; 8/36] START learning_rate=0.08, max_depth=12, n_estimators=500, num_leaves=20
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008927 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2586
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050660
# [CV 4/5; 8/36] END learning_rate=0.08, max_depth=12, n_estimators=500, num_leaves=20;, score=-0.026 total time=   5.9s
# [CV 4/5; 9/36] START learning_rate=0.08, max_depth=12, n_estimators=700, num_leaves=15
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.012091 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2586
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050660
# [CV 4/5; 9/36] END learning_rate=0.08, max_depth=12, n_estimators=700, num_leaves=15;, score=-0.026 total time=   7.2s
# [CV 5/5; 10/36] START learning_rate=0.08, max_depth=12, n_estimators=700, num_leaves=20
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.017930 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2552
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.035255
# [CV 5/5; 10/36] END learning_rate=0.08, max_depth=12, n_estimators=700, num_leaves=20;, score=-0.023 total time=   8.1s
# [CV 5/5; 11/36] START learning_rate=0.08, max_depth=12, n_estimators=900, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003381 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2552
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.035255
# [CV 5/5; 11/36] END learning_rate=0.08, max_depth=12, n_estimators=900, num_leaves=15;, score=-0.023 total time=   7.0s
# [CV 5/5; 12/36] START learning_rate=0.08, max_depth=12, n_estimators=900, num_leaves=20
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.017551 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2552
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.035255
# [CV 5/5; 12/36] END learning_rate=0.08, max_depth=12, n_estimators=900, num_leaves=20;, score=-0.023 total time=  10.4s
# [CV 3/5; 14/36] START learning_rate=0.08, max_depth=15, n_estimators=500, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010003 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2585
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.051670[CV 5/5; 1/36] START learning_rate=0.08, max_depth=9, n_estimators=500, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007880 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2552
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.035255
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 5/5; 1/36] END learning_rate=0.08, max_depth=9, n_estimators=500, num_leaves=15;, score=-0.023 total time=   4.2s
# [CV 2/5; 2/36] START learning_rate=0.08, max_depth=9, n_estimators=500, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002019 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2581
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.052839
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 2/5; 2/36] END learning_rate=0.08, max_depth=9, n_estimators=500, num_leaves=20;, score=-0.026 total time=   4.6s
# [CV 2/5; 3/36] START learning_rate=0.08, max_depth=9, n_estimators=700, num_leaves=15
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.016752 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2581
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.052839
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 2/5; 3/36] END learning_rate=0.08, max_depth=9, n_estimators=700, num_leaves=15;, score=-0.027 total time=   6.5s
# [CV 2/5; 4/36] START learning_rate=0.08, max_depth=9, n_estimators=700, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003948 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2581
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.052839
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 2/5; 4/36] END learning_rate=0.08, max_depth=9, n_estimators=700, num_leaves=20;, score=-0.026 total time=   7.5s
# [CV 4/5; 5/36] START learning_rate=0.08, max_depth=9, n_estimators=900, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008641 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2586
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050660
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 4/5; 5/36] END learning_rate=0.08, max_depth=9, n_estimators=900, num_leaves=15;, score=-0.026 total time=   6.9s
# [CV 3/5; 6/36] START learning_rate=0.08, max_depth=9, n_estimators=900, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009753 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2585
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.051670
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 3/5; 6/36] END learning_rate=0.08, max_depth=9, n_estimators=900, num_leaves=20;, score=-0.028 total time=   8.2s
# [CV 2/5; 7/36] START learning_rate=0.08, max_depth=12, n_estimators=500, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001934 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2581
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.052839
# [CV 2/5; 7/36] END learning_rate=0.08, max_depth=12, n_estimators=500, num_leaves=15;, score=-0.027 total time=   4.1s
# [CV 2/5; 8/36] START learning_rate=0.08, max_depth=12, n_estimators=500, num_leaves=20
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.016051 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2581
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.052839
# [CV 2/5; 8/36] END learning_rate=0.08, max_depth=12, n_estimators=500, num_leaves=20;, score=-0.027 total time=   5.5s
# [CV 2/5; 9/36] START learning_rate=0.08, max_depth=12, n_estimators=700, num_leaves=15
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.010943 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2581
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.052839
# [CV 2/5; 9/36] END learning_rate=0.08, max_depth=12, n_estimators=700, num_leaves=15;, score=-0.027 total time=   7.8s
# [CV 3/5; 10/36] START learning_rate=0.08, max_depth=12, n_estimators=700, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005092 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2585
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.051670
# [CV 3/5; 10/36] END learning_rate=0.08, max_depth=12, n_estimators=700, num_leaves=20;, score=-0.027 total time=   6.8s
# [CV 3/5; 11/36] START learning_rate=0.08, max_depth=12, n_estimators=900, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005167 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2585
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.051670
# [CV 3/5; 11/36] END learning_rate=0.08, max_depth=12, n_estimators=900, num_leaves=15;, score=-0.028 total time=   6.8s
# [CV 3/5; 12/36] START learning_rate=0.08, max_depth=12, n_estimators=900, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009122 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2585
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.051670
# [CV 3/5; 12/36] END learning_rate=0.08, max_depth=12, n_estimators=900, num_leaves=20;, score=-0.028 total time=   8.4s
# [CV 3/5; 13/36] START learning_rate=0.08, max_depth=15, n_estimators=500, num_leaves=15
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.011593 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2585
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.051670
# [CV 3/5; 13/36] END learning_rate=0.08, max_depth=15, n_estimators=500, num_leaves=15;, score=-0.028 total time=   5.5s
# [CV 1/5; 13/36] START learning_rate=0.08, max_depth=15, n_estimators=500, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012076 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050187
# [CV 1/5; 13/36] END learning_rate=0.08, max_depth=15, n_estimators=500, num_leaves=15;, score=-0.026 total time=   4.0s
# [CV 5/5; 13/36] START learning_rate=0.08, max_depth=15, n_estimators=500, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003862 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2552
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.035255
# [CV 5/5; 13/36] END learning_rate=0.08, max_depth=15, n_estimators=500, num_leaves=15;, score=-0.023 total time=   4.1s
# [CV 2/5; 14/36] START learning_rate=0.08, max_depth=15, n_estimators=500, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007673 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2581
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.052839
# [CV 2/5; 14/36] END learning_rate=0.08, max_depth=15, n_estimators=500, num_leaves=20;, score=-0.026 total time=   4.5s
# [CV 2/5; 15/36] START learning_rate=0.08, max_depth=15, n_estimators=700, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002722 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2581
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.052839
# [CV 2/5; 15/36] END learning_rate=0.08, max_depth=15, n_estimators=700, num_leaves=15;, score=-0.027 total time=   6.5s
# [CV 2/5; 16/36] START learning_rate=0.08, max_depth=15, n_estimators=700, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007702 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2581
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.052839
# [CV 2/5; 16/36] END learning_rate=0.08, max_depth=15, n_estimators=700, num_leaves=20;, score=-0.027 total time=   6.4s
# [CV 2/5; 17/36] START learning_rate=0.08, max_depth=15, n_estimators=900, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004277 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2581
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.052839
# [CV 2/5; 17/36] END learning_rate=0.08, max_depth=15, n_estimators=900, num_leaves=15;, score=-0.027 total time=   6.8s
# [CV 2/5; 18/36] START learning_rate=0.08, max_depth=15, n_estimators=900, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003838 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2581
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.052839
# [CV 2/5; 18/36] END learning_rate=0.08, max_depth=15, n_estimators=900, num_leaves=20;, score=-0.027 total time=   8.6s
# [CV 1/5; 19/36] START learning_rate=0.05, max_depth=9, n_estimators=500, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004051 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050187
# [CV 1/5; 19/36] END learning_rate=0.05, max_depth=9, n_estimators=500, num_leaves=15;, score=-0.026 total time=   4.7s
# [CV 1/5; 20/36] START learning_rate=0.05, max_depth=9, n_estimators=500, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002007 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050187
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 1/5; 20/36] END learning_rate=0.05, max_depth=9, n_estimators=500, num_leaves=20;, score=-0.026 total time=   5.3s
# [CV 1/5; 21/36] START learning_rate=0.05, max_depth=9, n_estimators=700, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001881 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050187
# [CV 1/5; 21/36] END learning_rate=0.05, max_depth=9, n_estimators=700, num_leaves=15;, score=-0.026 total time=   6.3s
# [CV 1/5; 22/36] START learning_rate=0.05, max_depth=9, n_estimators=700, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009364 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050187
# ...
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2552
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.035255
# [CV 5/5; 31/36] END learning_rate=0.05, max_depth=15, n_estimators=500, num_leaves=15;, score=-0.023 total time=   3.9s
# [CV 4/5; 32/36] START learning_rate=0.05, max_depth=15, n_estimators=500, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009874 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2586
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050660
# [CV 4/5; 32/36] END learning_rate=0.05, max_depth=15, n_estimators=500, num_leaves=20;, score=-0.026 total time=   5.1s
# [CV 4/5; 33/36] START learning_rate=0.05, max_depth=15, n_estimators=700, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007968 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2586
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050660
# [CV 4/5; 33/36] END learning_rate=0.05, max_depth=15, n_estimators=700, num_leaves=15;, score=-0.026 total time=   5.7s
# [CV 4/5; 34/36] START learning_rate=0.05, max_depth=15, n_estimators=700, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010225 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2586
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050660
# [CV 4/5; 34/36] END learning_rate=0.05, max_depth=15, n_estimators=700, num_leaves=20;, score=-0.026 total time=   7.3s
# [CV 4/5; 35/36] START learning_rate=0.05, max_depth=15, n_estimators=900, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005991 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2586
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050660
# [CV 4/5; 35/36] END learning_rate=0.05, max_depth=15, n_estimators=900, num_leaves=15;, score=-0.026 total time=   7.9s
# [CV 4/5; 36/36] START learning_rate=0.05, max_depth=15, n_estimators=900, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003945 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2586
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050660
# [CV 4/5; 36/36] END learning_rate=0.05, max_depth=15, n_estimators=900, num_leaves=20;, score=-0.026 total time=   7.7s
#
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050187
# [CV 1/5; 27/36] END learning_rate=0.05, max_depth=12, n_estimators=700, num_leaves=15;, score=-0.026 total time=   6.7s
# [CV 1/5; 28/36] START learning_rate=0.05, max_depth=12, n_estimators=700, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001936 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050187
# [CV 1/5; 28/36] END learning_rate=0.05, max_depth=12, n_estimators=700, num_leaves=20;, score=-0.026 total time=   6.7s
# [CV 1/5; 29/36] START learning_rate=0.05, max_depth=12, n_estimators=900, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009753 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050187
# [CV 1/5; 29/36] END learning_rate=0.05, max_depth=12, n_estimators=900, num_leaves=15;, score=-0.026 total time=   8.2s
# [CV 1/5; 30/36] START learning_rate=0.05, max_depth=12, n_estimators=900, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005973 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050187
# [CV 1/5; 30/36] END learning_rate=0.05, max_depth=12, n_estimators=900, num_leaves=20;, score=-0.026 total time=   8.2s
# [CV 1/5; 31/36] START learning_rate=0.05, max_depth=15, n_estimators=500, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003942 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050187
# [CV 1/5; 31/36] END learning_rate=0.05, max_depth=15, n_estimators=500, num_leaves=15;, score=-0.026 total time=   4.3s
# [CV 3/5; 31/36] START learning_rate=0.05, max_depth=15, n_estimators=500, num_leaves=15
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009831 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2585
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.051670
# [CV 3/5; 31/36] END learning_rate=0.05, max_depth=15, n_estimators=500, num_leaves=15;, score=-0.027 total time=   5.6s
# [CV 3/5; 32/36] START learning_rate=0.05, max_depth=15, n_estimators=500, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004190 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2585
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.051670
# [CV 3/5; 32/36] END learning_rate=0.05, max_depth=15, n_estimators=500, num_leaves=20;, score=-0.028 total time=   4.5s
# [CV 3/5; 33/36] START learning_rate=0.05, max_depth=15, n_estimators=700, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017045 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2585
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.051670
# [CV 3/5; 33/36] END learning_rate=0.05, max_depth=15, n_estimators=700, num_leaves=15;, score=-0.027 total time=   6.1s
# [CV 3/5; 34/36] START learning_rate=0.05, max_depth=15, n_estimators=700, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008245 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2585
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.051670
# [CV 3/5; 34/36] END learning_rate=0.05, max_depth=15, n_estimators=700, num_leaves=20;, score=-0.028 total time=   6.7s
# [CV 3/5; 35/36] START learning_rate=0.05, max_depth=15, n_estimators=900, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001993 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2585
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.051670
# [CV 3/5; 35/36] END learning_rate=0.05, max_depth=15, n_estimators=900, num_leaves=15;, score=-0.027 total time=   8.0s
# [CV 3/5; 36/36] START learning_rate=0.05, max_depth=15, n_estimators=900, num_leaves=20
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.010776 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2585
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.051670
# [CV 3/5; 36/36] END learning_rate=0.05, max_depth=15, n_estimators=900, num_leaves=20;, score=-0.028 total time=   8.7s
#
# [LightGBM] [Info] Start training from score 13.050187
# [CV 1/5; 26/36] END learning_rate=0.05, max_depth=12, n_estimators=500, num_leaves=20;, score=-0.026 total time=   6.0s
# [CV 2/5; 27/36] START learning_rate=0.05, max_depth=12, n_estimators=700, num_leaves=15
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025929 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2581
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.052839
# [CV 2/5; 27/36] END learning_rate=0.05, max_depth=12, n_estimators=700, num_leaves=15;, score=-0.026 total time=   7.8s
# [CV 4/5; 28/36] START learning_rate=0.05, max_depth=12, n_estimators=700, num_leaves=20
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.016741 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2586
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050660
# [CV 4/5; 28/36] END learning_rate=0.05, max_depth=12, n_estimators=700, num_leaves=20;, score=-0.026 total time=   8.8s
# [CV 4/5; 29/36] START learning_rate=0.05, max_depth=12, n_estimators=900, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003552 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2586
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050660
# [CV 4/5; 29/36] END learning_rate=0.05, max_depth=12, n_estimators=900, num_leaves=15;, score=-0.026 total time=   8.6s
# [CV 5/5; 30/36] START learning_rate=0.05, max_depth=12, n_estimators=900, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005793 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2552
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.035255
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 5/5; 30/36] END learning_rate=0.05, max_depth=12, n_estimators=900, num_leaves=20;, score=-0.023 total time=   8.9s
# [CV 4/5; 31/36] START learning_rate=0.05, max_depth=15, n_estimators=500, num_leaves=15
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.015902 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2586
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.050660
# [CV 4/5; 31/36] END learning_rate=0.05, max_depth=15, n_estimators=500, num_leaves=15;, score=-0.027 total time=   5.3s
# [CV 5/5; 32/36] START learning_rate=0.05, max_depth=15, n_estimators=500, num_leaves=20
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.016673 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2552
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.035255
# [CV 5/5; 32/36] END learning_rate=0.05, max_depth=15, n_estimators=500, num_leaves=20;, score=-0.023 total time=   6.3s
# [CV 5/5; 33/36] START learning_rate=0.05, max_depth=15, n_estimators=700, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001707 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2552
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.035255
# [CV 5/5; 33/36] END learning_rate=0.05, max_depth=15, n_estimators=700, num_leaves=15;, score=-0.023 total time=   5.3s
# [CV 5/5; 34/36] START learning_rate=0.05, max_depth=15, n_estimators=700, num_leaves=20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001847 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2552
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.035255
# [CV 5/5; 34/36] END learning_rate=0.05, max_depth=15, n_estimators=700, num_leaves=20;, score=-0.023 total time=   7.2s
# [CV 5/5; 35/36] START learning_rate=0.05, max_depth=15, n_estimators=900, num_leaves=15
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002345 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2552
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.035255
# [CV 5/5; 35/36] END learning_rate=0.05, max_depth=15, n_estimators=900, num_leaves=15;, score=-0.023 total time=   7.6s
# [CV 5/5; 36/36] START learning_rate=0.05, max_depth=15, n_estimators=900, num_leaves=20
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009473 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2552
# [LightGBM] [Info] Number of data points in the train set: 12028, number of used features: 20
# [LightGBM] [Info] Start training from score 13.035255
# [CV 5/5; 36/36] END learning_rate=0.05, max_depth=15, n_estimators=900, num_leaves=20;, score=-0.023 total time=   7.8s

# %%
def save_submission(model, train, y_log, test, model_name, rmsle=best['RMSLE'].round(4)):
    model.fit(train, y_log)
    # prediction = model.predict(test)
    # prediction = np.expm1(prediction)
    prediction = np .expm1(model.predict(test))
    data_dir = '~/work/kaggle_kakr_housing/data'
    submission_path = join(data_dir, 'sample_submission.csv')
    submission = pd.read_csv(submission_path)
    submission['price'] = prediction
    submission_csv_path = '{}/harry_submission_{}_RMSLE_{}.csv'.format(data_dir, model_name, rmsle)
    submission.to_csv(submission_csv_path, index=False)
    print('{} saved!'.format(submission_csv_path))

print(param_gained.head())
# Out:
#     learning_rate  max_depth  n_estimators  num_leaves     score     RMSLE
# 22           0.05          9           900          15 -0.025745  0.160453
# 34           0.05         15           900          15 -0.025753  0.160476
# 27           0.05         12           700          20 -0.025762  0.160507
# 29           0.05         12           900          20 -0.025763  0.160507
# 21           0.05          9           700          20 -0.025783  0.160572

# %%
save_submission(model, train, y_log, test, 'lgbm', rmsle='0.6')
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001547 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2592
# [LightGBM] [Info] Number of data points in the train set: 15035, number of used features: 20
# [LightGBM] [Info] Start training from score 13.048122
# ~/work/kaggle_kakr_housing/data/harry_submission_lgbm_RMSLE_0.6.csv saved!

# %%
data_dir = '~/work/kaggle_kakr_housing/data'
submission_path = join(data_dir, 'sample_submission.csv')
submission = pd.read_csv(submission_path)

submission['price'] = prediction
submission.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 6
#       3 submission_path = join(data_dir, 'sample_submission.csv')
#       4 submission = pd.read_csv(submission_path)
# ----> 6 submission['price'] = prediction
#       7 submission.head()
#
# NameError: name 'prediction' is not defined

# %%
print(param_gained.head())
# Out:
#     learning_rate  max_depth  n_estimators  num_leaves     score     RMSLE
# 6            0.10         10           200          31 -0.026188  0.161828
# 24           0.10         20           200          31 -0.026245  0.162003
# 33           0.10         25           200          31 -0.026245  0.162003
# 15           0.10         15           200          31 -0.026364  0.162371
# 70           0.05         25           200          63 -0.026446  0.162623

# %%
print(param_gained.iloc[0])
# Out:
# learning_rate      0.100000
# max_depth         10.000000
# n_estimators     200.000000
# num_leaves        31.000000
# score             -0.026188
# RMSLE              0.161828
# Name: 6, dtype: float64

# %%
def AveragingBlending(models, x, y, sub_x):
    for m in models :
        m['model'].fit(x.values, y)

    predictions = np.column_stack([
        m['model'].predict(sub_x.values) for m in models
    ])
    return np.mean(predictions, axis=1)

y_pred = AveragingBlending(models, x, y, sub)

data_dir = '~/work/kaggle_kakr_housing/data'

submission_path = join(data_dir, 'sample_submission.csv')
submission = pd.read_csv(submission_path)

result = pd.DataFrame({
    'id' : sub_id,
    'price' : y_pred
})

result.head()
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003498 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2338
# [LightGBM] [Info] Number of data points in the train set: 15035, number of used features: 19
# [LightGBM] [Info] Start training from score 540682.653143
#       id         price
# 0  15035  5.489445e+05
# 1  15036  4.436552e+05
# 2  15037  1.345797e+06
# 3  15038  3.206119e+05
# 4  15039  3.180479e+05

# %%
my_submission_path = join(data_dir, 'harry_submission.csv')
result.to_csv(my_submission_path, index=False)
print(my_submission_path)
# Out:
# ~/work/kaggle_kakr_housing/data/harry_submission.csv

# %%
print(result.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(result.head())
#
# NameError: name 'result' is not defined
